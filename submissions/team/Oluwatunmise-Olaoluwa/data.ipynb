# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Energy_consumption.csv')

data
# Out:
#                Timestamp  Temperature   Humidity  SquareFootage  Occupancy  \
# 0    2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1    2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2    2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3    2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4    2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
# ..                   ...          ...        ...            ...        ...
# 995  2022-02-11 11:00:00    28.619382  48.850160    1080.087000          5
# 996  2022-02-11 12:00:00    23.836647  47.256435    1705.235156          4
# 997  2022-02-11 13:00:00    23.005340  48.720501    1320.285281          6
# 998  2022-02-11 14:00:00    25.138365  31.306459    1309.079719          3
# 999  2022-02-11 15:00:00    23.051165  42.615421    1018.140606          6
#
#     HVACUsage LightingUsage  RenewableEnergy  DayOfWeek Holiday  \
# ...

# %% [markdown]
# # Data Processing and Cleaning

# %%
data.describe()
# Out:
#        Temperature     Humidity  SquareFootage    Occupancy  RenewableEnergy  \
# count  1000.000000  1000.000000    1000.000000  1000.000000      1000.000000
# mean     24.982026    45.395412    1500.052488     4.581000        15.132813
# std       2.836850     8.518905     288.418873     2.865598         8.745917
# min      20.007565    30.015975    1000.512661     0.000000         0.006642
# 25%      22.645070    38.297722    1247.108548     2.000000         7.628385
# 50%      24.751637    45.972116    1507.967426     5.000000        15.072296
# 75%      27.418174    52.420066    1740.340165     7.000000        22.884064
# max      29.998671    59.969085    1999.982252     9.000000        29.965327
#
#        EnergyConsumption
# count        1000.000000
# mean           77.055873
# std             8.144112
# min            53.263278
# 25%            71.544690
# 50%            76.943696
# 75%            82.921742
# max            99.201120

# %%
data.isna().sum()
# Out:
# Timestamp            0
# Temperature          0
# Humidity             0
# SquareFootage        0
# Occupancy            0
# HVACUsage            0
# LightingUsage        0
# RenewableEnergy      0
# DayOfWeek            0
# Holiday              0
# EnergyConsumption    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # EDA

# %%
data.head()
# Out:
#             Timestamp  Temperature   Humidity  SquareFootage  Occupancy  \
# 0 2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1 2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2 2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3 2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4 2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
#
#   HVACUsage LightingUsage  RenewableEnergy  DayOfWeek Holiday  \
# 0        On           Off         2.774699     Monday      No
# 1        On            On        21.831384   Saturday      No
# 2       Off           Off         6.764672     Sunday      No
# 3       Off            On         8.623447  Wednesday      No
# 4        On           Off         3.071969     Friday      No
#
#    EnergyConsumption
# 0          75.364373
# 1          83.401855
# 2          78.270888
# 3          56.519850
# 4          70.811732

# %%
data.dtypes
# Out:
# Timestamp             object
# Temperature          float64
# Humidity             float64
# SquareFootage        float64
# Occupancy              int64
# HVACUsage             object
# LightingUsage         object
# RenewableEnergy      float64
# DayOfWeek             object
# Holiday               object
# EnergyConsumption    float64
# dtype: object

# %%
data['Timestamp'] = pd.to_datetime(data['Timestamp'], format='%Y-%m-%d %H:%M:%S')

#data.set_index('Timestamp', inplace=True)

data.dtypes
# Out:
# Timestamp            datetime64[ns]
# Temperature                 float64
# Humidity                    float64
# SquareFootage               float64
# Occupancy                     int64
# HVACUsage                    object
# LightingUsage                object
# RenewableEnergy             float64
# DayOfWeek                    object
# Holiday                      object
# EnergyConsumption           float64
# dtype: object

# %%
data.head()
# Out:
#             Timestamp  Temperature   Humidity  SquareFootage  Occupancy  \
# 0 2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1 2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2 2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3 2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4 2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
#
#   HVACUsage LightingUsage  RenewableEnergy  DayOfWeek Holiday  \
# 0        On           Off         2.774699     Monday      No
# 1        On            On        21.831384   Saturday      No
# 2       Off           Off         6.764672     Sunday      No
# 3       Off            On         8.623447  Wednesday      No
# 4        On           Off         3.071969     Friday      No
#
#    EnergyConsumption
# 0          75.364373
# 1          83.401855
# 2          78.270888
# 3          56.519850
# 4          70.811732

# %%
data["Holiday"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# # Visualize Trends (Daily, Weekly, Seasonal)

# %%
daily = data.resample('D', on='Timestamp')['EnergyConsumption'].mean()

weekly = data.resample('W', on='Timestamp')['EnergyConsumption'].mean()


plt.figure(figsize=(14, 6))
daily.plot(label='Daily', alpha=0.7)
weekly.plot(label='weekly', alpha=0.9)
plt.ylabel('Energy Consumption')
plt.title('Daily and Weekly Energy Consumption')
plt.legend()
plt.show()
